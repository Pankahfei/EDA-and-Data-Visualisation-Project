# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
act17 = pd.read_csv("../data/act_2017.csv")
act18 = pd.read_csv("../data/act_2018.csv")
act19 = pd.read_csv("../data/act_2019.csv")
#GDP_2019 = pd.read_csv('data/GDP data by county 2017_2019.csv')

# %% [markdown]
# ## ACT Data Cleaning (2017-2019)

# %%
act17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#To heck any missing value
act17.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
# To confirm the data type
act17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
act17['Composite'] = act17['Composite'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_74172/1961242180.py in <module>
# ----> 1 act17['Composite'] = act17['Composite'].astype('float')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
# Found "20.2x" as unique value

# %%
def replace_x(row):    
  return row.replace('x',"")           
act17['Composite'] = act17['Composite'].apply((replace_x))

# %%
act17['Composite'] = act17['Composite'].astype('float')

# %%
# convert % into numerical
def remove_percent(x):
    return float(str(x).strip('%'))/100

act17['Participation'] = act17['Participation'].map(remove_percent)
act18['Participation'] = act18['Participation'].map(remove_percent)
act19['Participation'] = act19['Participation'].map(remove_percent)

# %%
# Duplicates found 
act18[act18.duplicated()]
# Out:
#     State  Participation  Composite
# 20  Maine           0.07       24.0

# %%
#Drop duplicates
act18 = act18.drop_duplicates()

# %%
sat18.duplicated().sum()
# Out:
# 0

# %%
# Replace inconsistant string with other dataset 
act18['State'].replace('District of columbia','District of Columbia',inplace=True)

# %%
# 'National' row data is not included in analysis
act17.drop(act17[act17['State']=="National"].index, inplace=True)

# %%
act19.drop(act19[act19['State']=="National"].index, inplace=True)

# %%
act17.shape
# Out:
# (51, 7)

# %%
act18.shape
# Out:
# (51, 3)

# %%
## Confirm all data to be merged are in same shape
act19.shape
# Out:
# (51, 3)

# %%
# rename, strip, and lower case the columns name

def column_naming(year,test,row):
    row_n = [row[0].lower()]
    for i in row[1:]: 
        i = (str(test)+str(year)+"_"+str(i[0:4])).strip()
        i = i.lower()
        row_n.append(i)
    return row_n

# %%
act_columns_list_new = column_naming(17, 'ACT', act17.columns)
act17.columns = act_columns_list_new 
act_columns_list_new1 = column_naming(18, 'ACT', act18.columns)
act18.columns = act_columns_list_new1
act_columns_list_new2 = column_naming(19, 'ACT', act19.columns)
act19.columns = act_columns_list_new2

# %%
act17.head()
# Out:
#         state  act17_part  act17_engl  act17_math  act17_read  act17_scie  \
# 1     Alabama        1.00        18.9        18.4        19.7        19.4
# 2      Alaska        0.65        18.7        19.8        20.4        19.9
# 3     Arizona        0.62        18.6        19.8        20.1        19.8
# 4    Arkansas        1.00        18.9        19.0        19.7        19.5
# 5  California        0.31        22.5        22.7        23.1        22.2
#
#    act17_comp
# 1        19.2
# 2        19.8
# 3        19.7
# 4        19.4
# 5        22.8

# %%
# Merging 3 years data
combine_act1 = pd.merge(left =act17, right =act18, on = "state" , how ="outer")

# %%
combine_act2 = pd.merge(left = combine_act1, right = act19, on = "state", how="outer")

# %%
combine_act2.head()
# Out:
#         state  act17_part  act17_engl  act17_math  act17_read  act17_scie  \
# 0     Alabama        1.00        18.9        18.4        19.7        19.4
# 1      Alaska        0.65        18.7        19.8        20.4        19.9
# 2     Arizona        0.62        18.6        19.8        20.1        19.8
# 3    Arkansas        1.00        18.9        19.0        19.7        19.5
# 4  California        0.31        22.5        22.7        23.1        22.2
#
#    act17_comp  act18_part  act18_comp  act19_part  act19_comp
# 0        19.2        1.00        19.1        1.00        18.9
# 1        19.8        0.33        20.8        0.38        20.1
# 2        19.7        0.66        19.2        0.73        19.0
# 3        19.4        1.00        19.4        1.00        19.3
# 4        22.8        0.27        22.7        0.23        22.6

# %%
combine_act2.to_csv("../data/act_combine.csv")

# %% [markdown]
# ## SAT Data Cleaning 2017-2019

# %%
sat17 = pd.read_csv("../data/sat_2017.csv")
sat18 = pd.read_csv("../data/sat_2018.csv")
sat19 = pd.read_csv("../data/sat_2019.csv")

# %%
sat19.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
sat17.head(2)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5%                                 593   572   1165
# 1   Alaska           38%                                 547   533   1080

# %%
sat18.head(2)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            6%                                 595   571   1166
# 1   Alaska           43%                                 562   544   1106

# %%
sat19.head(2)
# Out:
#      State Participation Rate  EBRW  Math  Total
# 0  Alabama                 7%   583   560   1143
# 1   Alaska                41%   556   541   1097

# %%
# sat19 has two more rows than other data
sat19.shape
# Out:
# (53, 5)

# %%
sat19.duplicated().sum()
# Out:
# 0

# %%
sat19['Participation Rate'].value_counts(ascending=True)
# Out:
# 22%     1
# 20%     1
# 9%      1
# 81%     1
# 79%     1
# 5%      1
# 2%      1
# 19%     1
# 95%     1
# 18%     1
# 71%     1
# 94%     1
# 63%     1
# 6%      1
# 31%     1
# 41%     1
# 54%     1
# 70%     2
# 51%     2
# 7%      2
# 99%     2
# —       2
# 66%     2
# 82%     2
# 68%     3
# 4%      5
# 3%      6
# 100%    8
# Name: Participation Rate, dtype: int64

# %%
sat19[sat19['Participation Rate']=="—"]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 47  Virgin Islands                  —   490   445    935

# %%
sat19.drop((sat19[(sat19['State']=="Puerto Rico")|(sat19['State']=="Virgin Islands")]).index, inplace = True)

# %%
sat19[sat19['Participation Rate']=="—"]
# Out:
# Empty DataFrame
# Columns: [State, Participation Rate, EBRW, Math, Total]
# Index: []

# %%
sat19.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
sat_columns_list_new = column_naming(17, 'SAT', sat17.columns)
sat17.columns = sat_columns_list_new 
sat_columns_list_new1 = column_naming(18, 'SAT', sat18.columns)
sat18.columns = sat_columns_list_new1
sat_columns_list_new2 = column_naming(19, 'SAT', sat19.columns)
sat19.columns = sat_columns_list_new2

# %%
sat17.head()
# Out:
#         state sat17_part  sat17_evid  sat17_math  sat17_tota
# 0     Alabama         5%         593         572        1165
# 1      Alaska        38%         547         533        1080
# 2     Arizona        30%         563         553        1116
# 3    Arkansas         3%         614         594        1208
# 4  California        53%         531         524        1055

# %%
sat17['sat17_part'] = sat17['sat17_part'].map(remove_percent)
sat18['sat18_part'] = sat18['sat18_part'].map(remove_percent)
sat19['sat19_part'] = sat19['sat19_part'].map(remove_percent)

# %%
sat19.head()
# Out:
#         state  sat19_part  sat19_ebrw  sat19_math  sat19_tota
# 0     Alabama        0.07         583         560        1143
# 1      Alaska        0.41         556         541        1097
# 2     Arizona        0.31         569         565        1134
# 3    Arkansas        0.06         582         559        1141
# 4  California        0.63         534         531        1065

# %%
sat17.rename(columns = {'sat17_evid':'sat17_ebrw'}, inplace = True)
sat18.rename(columns = {'sat18_evid':'sat18_ebrw'}, inplace = True)

# %%
sat18.head(2)
# Out:
#      state  sat18_part  sat18_ebrw  sat18_math  sat18_tota
# 0  Alabama        0.06         595         571        1166
# 1   Alaska        0.43         562         544        1106

# %%
# Merging 3 years data
combine_sat1 = pd.merge(left =sat17, right =sat18, on = "state" , how ="outer")

# %%
combine_sat2 = pd.merge(left = combine_sat1, right = sat19, on = "state", how="outer")

# %%
combine_sat2.head()
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_tota  sat18_part  \
# 0     Alabama        0.05         593         572        1165        0.06
# 1      Alaska        0.38         547         533        1080        0.43
# 2     Arizona        0.30         563         553        1116        0.29
# 3    Arkansas        0.03         614         594        1208        0.05
# 4  California        0.53         531         524        1055        0.60
#
#    sat18_ebrw  sat18_math  sat18_tota  sat19_part  sat19_ebrw  sat19_math  \
# 0         595         571        1166        0.07         583         560
# 1         562         544        1106        0.41         556         541
# 2         577         572        1149        0.31         569         565
# 3         592         576        1169        0.06         582         559
# 4         540         536        1076        0.63         534         531
#
#    sat19_tota
# 0        1143
# 1        1097
# 2        1134
# ...

# %%
combine_sat2.to_csv('../data/sat_combine.csv')

# %% [markdown]
# ## Merging ACT and SAT file

# %%
sat_act_combine = pd.merge(left =combine_act2, right =combine_sat2, on = "state" , how ="inner")

# %%
sat_act_combine.head()
# Out:
#         state  act17_part  act17_engl  act17_math  act17_read  act17_scie  \
# 0     Alabama        1.00        18.9        18.4        19.7        19.4
# 1      Alaska        0.65        18.7        19.8        20.4        19.9
# 2     Arizona        0.62        18.6        19.8        20.1        19.8
# 3    Arkansas        1.00        18.9        19.0        19.7        19.5
# 4  California        0.31        22.5        22.7        23.1        22.2
#
#    act17_comp  act18_part  act18_comp  act19_part  ...  sat17_math  \
# 0        19.2        1.00        19.1        1.00  ...         572
# 1        19.8        0.33        20.8        0.38  ...         533
# 2        19.7        0.66        19.2        0.73  ...         553
# 3        19.4        1.00        19.4        1.00  ...         594
# 4        22.8        0.27        22.7        0.23  ...         524
#
#    sat17_tota  sat18_part  sat18_ebrw  sat18_math  sat18_tota  sat19_part  \
# ...

# %%
sat_act_combine.to_csv('../data/act_sat_merged.csv')

# %% [markdown]
# ## Cross Check

# %%
act_sat_merged1 = pd.read_csv("../data/act_sat_merged_ethan.csv")

# %%
act_sat_merged1.describe()
# Out:
#        Unnamed: 0  act17_part  act17_eng  act17_math  act17_read  act17_sci  \
# count   51.000000   51.000000  51.000000   51.000000   51.000000  51.000000
# mean    25.000000    0.652549  20.931373   21.182353   22.013725  21.041176
# std     14.866069    0.321408   2.353677    1.981989    2.067271   3.182463
# min      0.000000    0.080000  16.300000   18.000000   18.100000   2.300000
# 25%     12.500000    0.310000  19.000000   19.400000   20.450000  19.900000
# 50%     25.000000    0.690000  20.700000   20.900000   21.800000  21.300000
# 75%     37.500000    1.000000  23.300000   23.100000   24.150000  22.750000
# max     50.000000    1.000000  25.500000   25.300000   26.000000  24.900000
#
#        act17_comp  act18_part  act18_comp  act19_part  ...  sat17_math  \
# count   51.000000   51.000000   51.000000   51.000000  ...   51.000000
# mean    21.519608    0.617255   21.496078    0.586667  ...  547.627451
# ...

# %%
act_sat_merged1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   51 non-null     int64
#  1   state        51 non-null     object
#  2   act17_part   51 non-null     float64
#  3   act17_eng    51 non-null     float64
#  4   act17_math   51 non-null     float64
#  5   act17_read   51 non-null     float64
#  6   act17_sci    51 non-null     float64
#  7   act17_comp   51 non-null     float64
#  8   act18_part   51 non-null     float64
#  9   act18_comp   51 non-null     float64
#  10  act19_part   51 non-null     float64
#  11  act19_comp   51 non-null     float64
#  12  sat17_part   51 non-null     float64
#  13  sat17_ebrw   51 non-null     int64
#  14  sat17_math   51 non-null     int64
#  15  sat17_total  51 non-null     int64
#  16  sat18_part   51 non-null     float64
#  17  sat18_ebrw   51 non-null     int64
# ...

# %%
sat_act_combine.describe()
# Out:
#        act17_part  act17_engl  act17_math  act17_read  act17_scie  act17_comp  \
# count   51.000000   51.000000   51.000000   51.000000   51.000000   51.000000
# mean     0.652549   20.931373   21.182353   22.013725   21.041176   21.519608
# std      0.321408    2.353677    1.981989    2.067271    3.182463    2.020695
# min      0.080000   16.300000   18.000000   18.100000    2.300000   17.800000
# 25%      0.310000   19.000000   19.400000   20.450000   19.900000   19.800000
# 50%      0.690000   20.700000   20.900000   21.800000   21.300000   21.400000
# 75%      1.000000   23.300000   23.100000   24.150000   22.750000   23.600000
# max      1.000000   25.500000   25.300000   26.000000   24.900000   25.500000
#
#        act18_part  act18_comp  act19_part  act19_comp  ...  sat17_math  \
# count   51.000000   51.000000   51.000000   51.000000  ...   51.000000
# mean     0.617255   21.496078    0.586667   21.464706  ...  547.627451
# ...

# %%
sat_act_combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   state       51 non-null     object
#  1   act17_part  51 non-null     float64
#  2   act17_engl  51 non-null     float64
#  3   act17_math  51 non-null     float64
#  4   act17_read  51 non-null     float64
#  5   act17_scie  51 non-null     float64
#  6   act17_comp  51 non-null     float64
#  7   act18_part  51 non-null     float64
#  8   act18_comp  51 non-null     float64
#  9   act19_part  51 non-null     float64
#  10  act19_comp  51 non-null     float64
#  11  sat17_part  51 non-null     float64
#  12  sat17_ebrw  51 non-null     int64
#  13  sat17_math  51 non-null     int64
#  14  sat17_tota  51 non-null     int64
#  15  sat18_part  51 non-null     float64
#  16  sat18_ebrw  51 non-null     int64
#  17  sat18_math  51 non-null     int64
#  18  sat18_tota  51 non-null     int64
# ...

# %% [markdown]
# ## Califonia data cleaning

# %%
act19_ca = pd.read_csv('../data/act_2019_ca.csv')

# %%
act19_ca.head(2)
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
#
#                              SName             DName        CName  Enroll12  \
# 0  21st Century Learning Institute  Beaumont Unified    Riverside      18.0
# 1      ABC Secondary (Alternative)       ABC Unified  Los Angeles      58.0
#
#    NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21 PctGE21  \
# 0         0.0        NaN       NaN        NaN       NaN     NaN     NaN
# 1         0.0        NaN       NaN        NaN       NaN     NaN     NaN
#
#       Year  Unnamed: 17
# 0  2018-19          NaN
# 1  2018-19          NaN

# %%
act19_ca.info()
#All score need to be in float and time in datetime format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
act19_ca.drop(columns = 'Unnamed: 17',inplace=True)

# %%
act19_ca.isnull().sum()
# Out:
# CDS             1
# CCode           1
# CDCode          1
# SCode         523
# RType           1
# SName         581
# DName          59
# CName           1
# Enroll12        1
# NumTstTakr      1
# AvgScrRead    357
# AvgScrEng     357
# AvgScrMath    357
# AvgScrSci     357
# NumGE21       357
# PctGE21       357
# Year            1
# dtype: int64

# %%
act19_ca[act19_ca['CDS'].isnull()]
# Out:
#       CDS  CCode  CDCode  SCode RType SName DName CName  Enroll12  NumTstTakr  \
# 2309  NaN    NaN     NaN    NaN   NaN   NaN   NaN   NaN       NaN         NaN
#
#      AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21 PctGE21 Year
# 2309        NaN       NaN        NaN       NaN     NaN     NaN  NaN

# %%
act19_ca.drop(2309,inplace=True)

# %%
act19_ca.isnull().sum()
# Out:
# CDS             0
# CCode           0
# CDCode          0
# SCode         522
# RType           0
# SName         580
# DName          58
# CName           0
# Enroll12        0
# NumTstTakr      0
# AvgScrRead    356
# AvgScrEng     356
# AvgScrMath    356
# AvgScrSci     356
# NumGE21       356
# PctGE21       356
# Year            0
# dtype: int64

# %%
#Found asterisk for certain row of score
act19_ca['PctGE21'].value_counts(ascending=False)
# Out:
# *        532
# 50.00     22
# 33.33     10
# 0.00       9
# 55.56      9
#         ...
# 6.56       1
# 8.00       1
# 80.81      1
# 24.53      1
# 57.58      1
# Name: PctGE21, Length: 915, dtype: int64

# %%
# No duplication
act19_ca.duplicated().sum()
# Out:
# 0

# %%
act19_ca['NumTstTakr'].mean()
# Out:
# 143.18276310090948

# %%
act19_ca[act19_ca['AvgScrRead']=="*"]['NumTstTakr'].mean()
# Out:
# 5.364661654135339

# %%
act19_ca[act19_ca['AvgScrRead'].isnull()]['NumTstTakr'].mean()
# Out:
# 0.0

# %% [markdown]
# #### Average number of total test taker is 143, but for the rows with unidentify score, only average of 5 test taker.
# #### Average number of total test taker is 0 for rows with null test score
# #### So, we can ignore those value first
# #### By this way, the analysis on the participation rate of each area would not be affected

# %%
act19_ca.replace('*' , np.nan, inplace=True)

# %%
## Confirming
act19_ca['PctGE21'].value_counts(ascending=False)
# Out:
# 50.00    22
# 33.33    10
# 28.57     9
# 0.00      9
# 55.56     9
#          ..
# 6.56      1
# 8.00      1
# 80.81     1
# 24.53     1
# 57.58     1
# Name: PctGE21, Length: 914, dtype: int64

# %%
act19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
def change_to_float(x):
    try:
      return float(x)
    except:
      pass

act19_ca['AvgScrRead'] = act19_ca['AvgScrRead'].apply(change_to_float)
act19_ca['AvgScrEng'] = act19_ca['AvgScrEng'].apply(change_to_float)
act19_ca['AvgScrMath'] = act19_ca['AvgScrMath'].apply(change_to_float)
act19_ca['AvgScrSci'] = act19_ca['AvgScrSci'].apply(change_to_float)
act19_ca['NumGE21'] = act19_ca['NumGE21'].apply(change_to_float)
act19_ca['PctGE21'] = act19_ca['PctGE21'].apply(change_to_float)

# %%
act19_ca.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.309000e+03  2309.000000  2.309000e+03  1.787000e+03    2309.000000
# mean   2.929718e+13    28.666522  2.855616e+06  1.902681e+06     828.172802
# std    1.444996e+13    14.425498  1.492574e+06  1.838954e+06   10667.048988
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964519e+06  1.254385e+05      78.000000
# 50%    3.066647e+13    30.000000  3.066548e+06  1.930288e+06     218.000000
# 75%    3.868478e+13    38.000000  3.777032e+06  3.435674e+06     497.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#          NumTstTakr   AvgScrRead    AvgScrEng   AvgScrMath    AvgScrSci  \
# count   2309.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean     143.182763    22.075299    21.204082    21.416608    21.356791
# ...

# %%
act19_ca['Year'].value_counts()
# Out:
# 2018-19    2309
# Name: Year, dtype: int64

# %%
act19_ca['Year'].replace('2018-19','2019', inplace=True)

# %%
act19_ca['Year']=act19_ca['Year'].apply(pd.to_datetime).dt.year

# %%
act19_ca.dtypes
# Out:
# CDS           float64
# CCode         float64
# CDCode        float64
# SCode         float64
# RType          object
# SName          object
# DName          object
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead    float64
# AvgScrEng     float64
# AvgScrMath    float64
# AvgScrSci     float64
# NumGE21       float64
# PctGE21       float64
# Year            int64
# dtype: object

# %%
act19_ca.isnull().sum()
# Out:
# CDS             0
# CCode           0
# CDCode          0
# SCode         522
# RType           0
# SName         580
# DName          58
# CName           0
# Enroll12        0
# NumTstTakr      0
# AvgScrRead    888
# AvgScrEng     888
# AvgScrMath    888
# AvgScrSci     888
# NumGE21       888
# PctGE21       888
# Year            0
# dtype: int64

# %%
len(act19_ca['CName'].unique())
# Out:
# 59

# %%
act19_ca['CCode'].max()
# Out:
# 58.0

# %%
## R type columns verification
act19_ca['RType'].value_counts()
# Out:
# S    1728
# D     522
# C      58
# X       1
# Name: RType, dtype: int64

# %%
act19_ca.groupby('RType')['NumTstTakr'].sum()
# Out:
# RType
# C    82668.0
# D    82619.0
# S    82654.0
# X    82668.0
# Name: NumTstTakr, dtype: float64

# %%
act19_ca.groupby('RType')['NumGE21'].sum()
# Out:
# RType
# C    45455.0
# D    45118.0
# S    44372.0
# X    45466.0
# Name: NumGE21, dtype: float64

# %% [markdown]
# ### We can see that data categorized by county(C) and state(X) are very much comparable

# %%
# No duplication in 'CName' with R type = County
print(act19_ca[act19_ca['RType']=='C']['CName'].duplicated().sum())
# Out:
# 0

# %%
# 58 County in Califonia //https://en.wikipedia.org/wiki/List_of_counties_in_California
act19_ca[act19_ca['RType']=='C']['CName'].count()
# Out:
# 58

# %%
## if we only interested in data classified by county
act19_ca_c = act19_ca[act19_ca['RType']=='C']

# %%
act19_ca_c=act19_ca_c.reset_index(drop=True)

# %%
act19_ca_c = act19_ca_c.drop(columns=['CDCode','SCode','RType','SName','DName'])

# %%
act19_ca_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CDS         58 non-null     float64
#  1   CCode       58 non-null     float64
#  2   CName       58 non-null     object
#  3   Enroll12    58 non-null     float64
#  4   NumTstTakr  58 non-null     float64
#  5   AvgScrRead  54 non-null     float64
#  6   AvgScrEng   54 non-null     float64
#  7   AvgScrMath  54 non-null     float64
#  8   AvgScrSci   54 non-null     float64
#  9   NumGE21     54 non-null     float64
#  10  PctGE21     54 non-null     float64
#  11  Year        58 non-null     int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 5.6+ KB

# %%
act19_ca_c.isnull().sum()
# Out:
# CDS           0
# CCode         0
# CName         0
# Enroll12      0
# NumTstTakr    0
# AvgScrRead    4
# AvgScrEng     4
# AvgScrMath    4
# AvgScrSci     4
# NumGE21       4
# PctGE21       4
# Year          0
# dtype: int64

# %%
act19_ca_c.head()
# Out:
#             CDS  CCode        CName  Enroll12  NumTstTakr  AvgScrRead  \
# 0  3.400000e+13   34.0   Sacramento   19540.0      3065.0        21.0
# 1  3.900000e+13   39.0  San Joaquin   11778.0      1348.0        22.0
# 2  1.500000e+13   15.0         Kern   14229.0      1257.0        21.0
# 3  4.500000e+13   45.0       Shasta    2161.0       173.0        26.0
# 4  5.100000e+13   51.0       Sutter    1827.0       196.0        23.0
#
#    AvgScrEng  AvgScrMath  AvgScrSci  NumGE21  PctGE21  Year
# 0       20.0        21.0       21.0   1526.0    49.79  2019
# 1       21.0        21.0       21.0    693.0    51.41  2019
# 2       20.0        20.0       20.0    544.0    43.28  2019
# 3       24.0        24.0       24.0    131.0    75.72  2019
# 4       22.0        22.0       22.0    117.0    59.69  2019

# %%
act19_ca_c.to_csv('../data/act19_ca_bycounty.csv')

# %%
sat19_ca = pd.read_csv('../data/sat_2019_ca.csv')

# %%
sat19_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
# remove the unnessary columns (we only use grade 12(senior year) data here to compare with ACT data )
sat19_ca.drop(columns=['Enroll11','NumTSTTakr11','NumERWBenchmark11','PctERWBenchmark11','NumMathBenchmark11','PctMathBenchmark11',
                      'TotNumBothBenchmark11','PctBothBenchmark11','Unnamed: 25'],inplace=True)

# %%
sat19_ca.dtypes
# Out:
# CDS                      float64
# CCode                    float64
# CDCode                   float64
# SCode                    float64
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# PctERWBenchmark12         object
# NumMathBenchmark12        object
# PctMathBenchmark12        object
# TotNumBothBenchmark12     object
# PctBothBenchmark12        object
# Year                      object
# dtype: object

# %%
sat19_ca['NumERWBenchmark12'] = sat19_ca['NumERWBenchmark12'].apply(change_to_float)
sat19_ca['PctERWBenchmark12'] = sat19_ca['PctERWBenchmark12'].apply(change_to_float)
sat19_ca['NumMathBenchmark12'] = sat19_ca['NumMathBenchmark12'].apply(change_to_float)
sat19_ca['PctMathBenchmark12'] = sat19_ca['PctMathBenchmark12'].apply(change_to_float)
sat19_ca['TotNumBothBenchmark12'] = sat19_ca['TotNumBothBenchmark12'].apply(change_to_float)
sat19_ca['PctBothBenchmark12'] = sat19_ca['PctBothBenchmark12'].apply(change_to_float)

# %%
sat19_ca.isnull().sum()
# Out:
# CDS                        1
# CCode                      1
# CDCode                     1
# SCode                      1
# RType                      1
# SName                    598
# DName                     59
# CName                      1
# Enroll12                   1
# NumTSTTakr12               1
# NumERWBenchmark12        858
# PctERWBenchmark12        858
# NumMathBenchmark12       858
# PctMathBenchmark12       858
# TotNumBothBenchmark12    858
# PctBothBenchmark12       858
# Year                       1
# dtype: int64

# %%
sat19_ca[sat19_ca['Year'].isnull()]
# Out:
#       CDS  CCode  CDCode  SCode RType SName DName CName  Enroll12  \
# 2579  NaN    NaN     NaN    NaN   NaN   NaN   NaN   NaN       NaN
#
#       NumTSTTakr12  NumERWBenchmark12  PctERWBenchmark12  NumMathBenchmark12  \
# 2579           NaN                NaN                NaN                 NaN
#
#       PctMathBenchmark12  TotNumBothBenchmark12  PctBothBenchmark12 Year
# 2579                 NaN                    NaN                 NaN  NaN

# %%
sat19_ca.drop(2579, inplace=True)

# %%
sat19_ca.isnull().sum()
# Out:
# CDS                        0
# CCode                      0
# CDCode                     0
# SCode                      0
# RType                      0
# SName                    597
# DName                     58
# CName                      0
# Enroll12                   0
# NumTSTTakr12               0
# NumERWBenchmark12        857
# PctERWBenchmark12        857
# NumMathBenchmark12       857
# PctMathBenchmark12       857
# TotNumBothBenchmark12    857
# PctBothBenchmark12       857
# Year                       0
# dtype: int64

# %%
sat19_ca['Year'].replace('2018-19','2019', inplace=True)
sat19_ca['Year']=sat19_ca['Year'].apply(pd.to_datetime).dt.year

# %%
sat19_ca.duplicated().sum()
# Out:
# 0

# %%
sat19_ca.replace('*',np.nan)
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 0     6.615981e+12    6.0   661598.0   630046.0     S
# 1     6.616061e+12    6.0   661606.0   634758.0     S
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# ...            ...    ...        ...        ...   ...
# 2574  5.075556e+13   50.0  5075556.0        0.0     D
# 2575  5.772678e+13   57.0  5772678.0        0.0     D
# 2576  7.000000e+12    7.0   700000.0        0.0     C
# 2577  1.700000e+13   17.0  1700000.0        0.0     C
# 2578  3.800000e+13   38.0  3800000.0        0.0     C
#
#                         SName                DName          CName  Enroll12  \
# 0     Colusa Alternative Home       Colusa Unified         Colusa      18.0
# 1             Maxwell Sr High      Maxwell Unified         Colusa      29.0
# 2         Belmont Senior High  Los Angeles Unified    Los Angeles     206.0
# ...

# %%
sat19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  \
# 0       Colusa Unified       Colusa      18.0           0.0
# 1      Maxwell Unified       Colusa      29.0          10.0
# 2  Los Angeles Unified  Los Angeles     206.0         102.0
# 3  Los Angeles Unified  Los Angeles     227.0         113.0
# 4  Los Angeles Unified  Los Angeles      18.0          14.0
#
#    NumERWBenchmark12  PctERWBenchmark12  NumMathBenchmark12  \
# 0                NaN                NaN                 NaN
# ...

# %%
sat19_ca_c = sat19_ca[sat19_ca['RType']=='C']

# %%
sat19_ca_c = sat19_ca_c.drop(columns=['CDCode','SCode','RType','SName','DName'])

# %%
sat19_ca_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1981 to 2578
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    58 non-null     float64
#  1   CCode                  58 non-null     float64
#  2   CName                  58 non-null     object
#  3   Enroll12               58 non-null     float64
#  4   NumTSTTakr12           58 non-null     float64
#  5   NumERWBenchmark12      55 non-null     float64
#  6   PctERWBenchmark12      55 non-null     float64
#  7   NumMathBenchmark12     55 non-null     float64
#  8   PctMathBenchmark12     55 non-null     float64
#  9   TotNumBothBenchmark12  55 non-null     float64
#  10  PctBothBenchmark12     55 non-null     float64
#  11  Year                   58 non-null     int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 5.9+ KB

# %%
sat19_ca_c[sat19_ca_c['NumERWBenchmark12'].isnull()]['NumTSTTakr12'].mean()
# Out:
# 6.0

# %%
sat19_ca_c['NumTSTTakr12'].mean()
# Out:
# 2938.1206896551726

# %% [markdown]
# ### Hence, the null value is due to insignificant number of testtaker

# %%
sat19_ca_c = sat19_ca_c.reset_index(drop=True)

# %%
sat19_ca_c.head()
# Out:
#             CDS  CCode        CName  Enroll12  NumTSTTakr12  \
# 0  9.000000e+12    9.0    El Dorado    2226.0         604.0
# 1  1.900000e+13   19.0  Los Angeles  114618.0       48676.0
# 2  2.000000e+13   20.0       Madera    2352.0         442.0
# 3  5.700000e+13   57.0         Yolo    2299.0         759.0
# 4  1.500000e+13   15.0         Kern   14229.0        3793.0
#
#    NumERWBenchmark12  PctERWBenchmark12  NumMathBenchmark12  \
# 0              547.0              90.56               458.0
# 1            30081.0              61.80             19791.0
# 2              277.0              62.67               136.0
# 3              586.0              77.21               464.0
# 4             2334.0              61.53              1481.0
#
#    PctMathBenchmark12  TotNumBothBenchmark12  PctBothBenchmark12  Year
# 0               75.83                  442.0               73.18  2019
# 1               40.66                18555.0               38.12  2019
# ...

# %%
sat19_ca_c.to_csv('../data/sat19_ca_bycounty.csv')

# %% [markdown]
# ## GDP Data Cleaning

# %%
GDP_data = pd.read_csv('../data/GDP data by county 2017_2019.csv',skiprows=4)

# %%
GDP_data.head()
# Out:
#   GeoFips      GeoName     2017     2018     2019
# 0   01001  Autauga, AL  1587695  1602077  1540762
# 1   01003  Baldwin, AL  6453588  6799715  7134734
# 2   01005  Barbour, AL   721125   730518   729105
# 3   01007     Bibb, AL   353234   353016   380453
# 4   01009   Blount, AL   920401   967135   932215

# %%
GDP_data.isnull().sum()
# Out:
# GeoFips     0
# GeoName    11
# 2017       11
# 2018       11
# 2019       11
# dtype: int64

# %%
GDP_data[GDP_data['GeoName'].isnull()].index
# Out:
# Int64Index([3118, 3119, 3120, 3121, 3122, 3123, 3124, 3125, 3126, 3127, 3128], dtype='int64')

# %%
GDP_data.dropna(inplace=True)

# %%
GDP_data.isnull().sum()
# Out:
# GeoFips    0
# GeoName    0
# 2017       0
# 2018       0
# 2019       0
# dtype: int64

# %%
GDP_data['GeoName'].str.contains('CA').sum()
# Out:
# 58

# %%
GDP_data = GDP_data[GDP_data['GeoName'].str.contains('CA')]

# %%
GDP_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 191 to 248
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   GeoFips  58 non-null     object
#  1   GeoName  58 non-null     object
#  2   2017     58 non-null     object
#  3   2018     58 non-null     object
#  4   2019     58 non-null     object
# dtypes: object(5)
# memory usage: 2.7+ KB

# %%
GDP_data = GDP_data.reset_index(drop=True)

# %%
GDP_data[['CName','State']] = GDP_data['GeoName'].str.split(',',expand=True)

# %%
GDP_data.head()
# Out:
#   GeoFips        GeoName       2017       2018       2019      CName State
# 0   06001    Alameda, CA  119117078  123718310  126183638    Alameda    CA
# 1   06003     Alpine, CA      99643     100131     104501     Alpine    CA
# 2   06005     Amador, CA    1570431    1585410    1625096     Amador    CA
# 3   06007      Butte, CA    8434322    8543593    8701260      Butte    CA
# 4   06009  Calaveras, CA    1292735    1238320    1412753  Calaveras    CA

# %%
def change_to_float(x):
    try:
      return float(x)
    except:
      pass
GDP_data['2017'] = GDP_data['2017'].apply(change_to_float)*1000
GDP_data['2018'] = GDP_data['2018'].apply(change_to_float)*1000
GDP_data['2019'] = GDP_data['2019'].apply(change_to_float)*1000

# %%
GDP_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   GeoFips  58 non-null     object
#  1   GeoName  58 non-null     object
#  2   2017     58 non-null     float64
#  3   2018     58 non-null     float64
#  4   2019     58 non-null     float64
#  5   CName    58 non-null     object
#  6   State    58 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 3.3+ KB

# %%
GDP_data.dtypes
# Out:
# GeoFips     object
# GeoName     object
# 2017       float64
# 2018       float64
# 2019       float64
# CName       object
# State       object
# dtype: object

# %%
GDP_data.to_csv("../data/Clean_GDP_ca.csv")

# %%
print(act19_ca_c.shape)
print(sat19_ca_c.shape)
print(GDP_data.shape)
# Out:
# (58, 12)
# (58, 12)
# (58, 7)

# %% [markdown]
# ## Combine with Population data

# %%
popu = pd.read_excel('../data/datapile_-_headline_datasets_-_current.xlsx', sheet_name='People')

# %%
popu.head()
# Out:
#       County  Population (January 2019)  \
# 0    Alameda                    1669301
# 1     Alpine                       1162
# 2     Amador                      38294
# 3      Butte                     226466
# 4  Calaveras                      45117
#
#    Population in Group Quarters (January 2019)  \
# 0                                        39821
# 1                                           24
# 2                                         4362
# 3                                         4970
# 4                                          507
#
#    Population: Unincorporated (January 2019)  \
# 0                                     149536
# 1                                       1162
# 2                                      21774
# 3                                      78702
# 4                                      41277
#
#    Population: Unincorporated, Group Quarters (January 2019)  \
# 0                                             2356.0
# ...

# %%
popu = popu[['County','Population (January 2019)','Median Household Income (2017)']]

# %%
popu.head()
# Out:
#       County  Population (January 2019)  Median Household Income (2017)
# 0    Alameda                    1669301                           95550
# 1     Alpine                       1162                           55755
# 2     Amador                      38294                           60588
# 3      Butte                     226466                           48634
# 4  Calaveras                      45117                           58536

# %%
GDP_Popu = pd.merge(left = GDP_data,
                   right = popu,
                   left_on = "CName",
                   right_on = "County")

# %%
GDP_Popu.head()
# Out:
#   GeoFips        GeoName          2017          2018          2019      CName  \
# 0   06001    Alameda, CA  1.191171e+11  1.237183e+11  1.261836e+11    Alameda
# 1   06003     Alpine, CA  9.964300e+07  1.001310e+08  1.045010e+08     Alpine
# 2   06005     Amador, CA  1.570431e+09  1.585410e+09  1.625096e+09     Amador
# 3   06007      Butte, CA  8.434322e+09  8.543593e+09  8.701260e+09      Butte
# 4   06009  Calaveras, CA  1.292735e+09  1.238320e+09  1.412753e+09  Calaveras
#
#   State     County  Population (January 2019)  Median Household Income (2017)
# 0    CA    Alameda                    1669301                           95550
# 1    CA     Alpine                       1162                           55755
# 2    CA     Amador                      38294                           60588
# 3    CA      Butte                     226466                           48634
# 4    CA  Calaveras                      45117                           58536

# %%
GDP_Popu.to_csv("../data/Clean_GDP&Population_ca.csv")

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
ACT19_ca = pd.read_csv("../data/clean data/act19_ca_bycounty.csv")
SAT19_ca = pd.read_csv("../data/clean data/sat19_ca_bycounty.csv")

# %%
ACT19_ca.head()
# Out:
#    Unnamed: 0           CDS  CCode        CName  Enroll12  NumTstTakr  \
# 0           0  3.400000e+13   34.0   Sacramento   19540.0      3065.0
# 1           1  3.900000e+13   39.0  San Joaquin   11778.0      1348.0
# 2           2  1.500000e+13   15.0         Kern   14229.0      1257.0
# 3           3  4.500000e+13   45.0       Shasta    2161.0       173.0
# 4           4  5.100000e+13   51.0       Sutter    1827.0       196.0
#
#    AvgScrRead  AvgScrEng  AvgScrMath  AvgScrSci  NumGE21  PctGE21  Year
# 0        21.0       20.0        21.0       21.0   1526.0    49.79  2019
# 1        22.0       21.0        21.0       21.0    693.0    51.41  2019
# 2        21.0       20.0        20.0       20.0    544.0    43.28  2019
# 3        26.0       24.0        24.0       24.0    131.0    75.72  2019
# 4        23.0       22.0        22.0       22.0    117.0    59.69  2019

# %%
SAT19_ca.head()
# Out:
#    Unnamed: 0           CDS  CCode        CName  Enroll12  NumTSTTakr12  \
# 0           0  9.000000e+12    9.0    El Dorado    2226.0         604.0
# 1           1  1.900000e+13   19.0  Los Angeles  114618.0       48676.0
# 2           2  2.000000e+13   20.0       Madera    2352.0         442.0
# 3           3  5.700000e+13   57.0         Yolo    2299.0         759.0
# 4           4  1.500000e+13   15.0         Kern   14229.0        3793.0
#
#    NumERWBenchmark12  PctERWBenchmark12  NumMathBenchmark12  \
# 0              547.0              90.56               458.0
# 1            30081.0              61.80             19791.0
# 2              277.0              62.67               136.0
# 3              586.0              77.21               464.0
# 4             2334.0              61.53              1481.0
#
#    PctMathBenchmark12  TotNumBothBenchmark12  PctBothBenchmark12  Year
# 0               75.83                  442.0               73.18  2019
# ...

# %%
ACT19_ca.describe()
# Out:
#        Unnamed: 0           CDS      CCode       Enroll12    NumTstTakr  \
# count   58.000000  5.800000e+01  58.000000      58.000000     58.000000
# mean    28.500000  2.950000e+13  29.500000    8442.241379   1425.310345
# std     16.886879  1.688688e+13  16.886879   17344.164490   3164.257498
# min      0.000000  1.000000e+12   1.000000       0.000000      0.000000
# 25%     14.250000  1.525000e+13  15.250000     525.500000     64.250000
# 50%     28.500000  2.950000e+13  29.500000    2325.500000    365.000000
# 75%     42.750000  4.375000e+13  43.750000    7477.250000   1212.250000
# max     57.000000  5.800000e+13  58.000000  114618.000000  20678.000000
#
#        AvgScrRead  AvgScrEng  AvgScrMath  AvgScrSci      NumGE21    PctGE21  \
# count   54.000000  54.000000   54.000000  54.000000    54.000000  54.000000
# mean    22.648148  21.537037   21.814815  21.722222   841.759259  56.757407
# std      2.466052   2.589623    2.137483   2.041241  1675.299939  17.189004
# ...

# %%
SAT19_ca.describe()
# Out:
#        Unnamed: 0           CDS      CCode       Enroll12  NumTSTTakr12  \
# count   58.000000  5.800000e+01  58.000000      58.000000     58.000000
# mean    28.500000  2.950000e+13  29.500000    8442.241379   2938.120690
# std     16.886879  1.688688e+13  16.886879   17344.164490   7079.370425
# min      0.000000  1.000000e+12   1.000000       0.000000      0.000000
# 25%     14.250000  1.525000e+13  15.250000     525.500000     90.250000
# 50%     28.500000  2.950000e+13  29.500000    2325.500000    579.500000
# 75%     42.750000  4.375000e+13  43.750000    7477.250000   2343.750000
# max     57.000000  5.800000e+13  58.000000  114618.000000  48676.000000
#
#        NumERWBenchmark12  PctERWBenchmark12  NumMathBenchmark12  \
# count          55.000000          55.000000           55.000000
# mean         2117.927273          74.402545         1482.545455
# std          4612.155846           9.793826         3131.258301
# ...

# %%
ACT19_ca[.isnull().value_counts()
# Out:
# Unnamed: 0  CDS    CCode  CName  Enroll12  NumTstTakr  AvgScrRead  AvgScrEng  AvgScrMath  AvgScrSci  NumGE21  PctGE21  Year   Participation_r  Pct_Rank  Pct_Percentie  Part_Percentie
# False       False  False  False  False     False       False       False      False       False      False    False    False  False            False     False          False             54
#                                                        True        True       True        True       True     True     False  False            True      True           False              3
#                                                                                                                               True             True      True           True               1
# dtype: int64

# %%
ACT19_ca['Participation_r_act'] = ACT19_ca['NumTstTakr']/ACT19_ca['Enroll12']   
SAT19_ca['Participation_r_sat'] = SAT19_ca['NumTSTTakr12']/SAT19_ca['Enroll12']

# %%
sns.jointplot(x='Enroll12', y ='Participation_r', data=ACT19_ca, kind='reg', ax=ax[1])
# no clear relation between enrollment and participation rate

# %%
sns.jointplot(y='PctGE21', x ='Participation_r_act', data=ACT19_ca, kind='reg', ax=ax[1])
# no clear relation between performance and participation rate

# %%
ACT19_ca['Pct_Rank'] = ACT19_ca['PctGE21'].rank(method='dense')
SAT19_ca['Pct_Rank'] = SAT19_ca['PctBothBenchmark12'].rank(method='dense')

# %%
ACT19_ca=ACT19_ca.sort_values(by=['Pct_Rank'], ascending=False)
SAT19_ca=SAT19_ca.sort_values(by=['Pct_Rank'], ascending=False)

# %%
print(ACT19_ca[:10][['CName'][0]])
# Out:
# 5       Calaveras
# 8           Marin
# 6            Mono
# 27         Amador
# 31       Tuolumne
# 53    Santa Clara
# 9       El Dorado
# 43         Placer
# 3          Shasta
# 56         Nevada
# Name: CName, dtype: object

# %%
print(SAT19_ca[:10][['CName'][0]])
# Out:
# 0           El Dorado
# 11           Mariposa
# 12             Placer
# 18              Marin
# 29             Nevada
# 50        Santa Clara
# 10          Calaveras
# 53             Plumas
# 44             Shasta
# 16    San Luis Obispo
# Name: CName, dtype: object

# %%
def classification_pct(x):
    if x > SAT19_ca['PctBothBenchmark12'].quantile(0.75):
        return "4th_quantile"
    elif x > SAT19_ca['PctBothBenchmark12'].quantile(0.5):
        return "3rd_quantile"
    elif x > SAT19_ca['PctBothBenchmark12'].quantile(0.25):
        return "2nd_quantile"
    elif x > 0:
        return "1st_quantile"
    else:
        return np.nan
    
SAT19_ca['Pct_Percentie'] = SAT19_ca['PctBothBenchmark12'].apply(classification_pct)

# %%
def classification_pct_ACT(x):
    if x > ACT19_ca['PctGE21'].quantile(0.75):
        return "4th_quantile"
    elif x > ACT19_ca['PctGE21'].quantile(0.5):
        return "3rd_quantile"
    elif x > ACT19_ca['PctGE21'].quantile(0.25):
        return "2nd_quantile"
    elif x > 0:
        return "1st_quantile"
    else:
        return np.nan
    
ACT19_ca['Pct_Percentie'] = ACT19_ca['PctGE21'].apply(classification_pct_ACT)

# %%
def classification_part_SAT(x):
    if x > SAT19_ca['Participation_r_sat'].quantile(0.75):
        return "4th_quantile"
    elif x > SAT19_ca['Participation_r_sat'].quantile(0.5):
        return "3rd_quantile"
    elif x > SAT19_ca['Participation_r_sat'].quantile(0.25):
        return "2nd_quantile"
    elif x > 0:
        return "1st_quantile"
    else:
        return np.nan
    
SAT19_ca['Part_Percentie'] = SAT19_ca['Participation_r_sat'].apply(classification_part_SAT)

# %%
def classification_part_ACT(x):
    if x > ACT19_ca['Participation_r_act'].quantile(0.75):
        return "4th_quantile"
    elif x > ACT19_ca['Participation_r_act'].quantile(0.5):
        return "3rd_quantile"
    elif x > ACT19_ca['Participation_r_act'].quantile(0.25):
        return "2nd_quantile"
    elif x > 0:
        return "1st_quantile"
    else:
        return np.nan
    
ACT19_ca['Part_Percentie'] = ACT19_ca['Participation_r_act'].apply(classification_part_ACT)

# %%
ACT19_ca.head()
# Out:
#     Unnamed: 0           CDS  CCode      CName  Enroll12  NumTstTakr  \
# 5            5  5.000000e+12    5.0  Calaveras     451.0        31.0
# 8            8  2.100000e+13   21.0      Marin    2647.0       753.0
# 6            6  2.600000e+13   26.0       Mono     420.0        20.0
# 27          27  3.000000e+12    3.0     Amador     305.0        37.0
# 31          31  5.500000e+13   55.0   Tuolumne     518.0        23.0
#
#     AvgScrRead  AvgScrEng  AvgScrMath  AvgScrSci  NumGE21  PctGE21  Year  \
# 5         26.0       24.0        24.0       24.0     27.0    87.10  2019
# 8         27.0       26.0        25.0       25.0    606.0    80.48  2019
# 6         26.0       24.0        24.0       24.0     16.0    80.00  2019
# 27        24.0       23.0        23.0       22.0     29.0    78.38  2019
# 31        26.0       23.0        23.0       23.0     18.0    78.26  2019
#
#     Participation_r  Pct_Rank Pct_Percentie Part_Percentie  \
# ...

# %%
SAT19_ca.head()
# Out:
#     Unnamed: 0           CDS  CCode      CName  Enroll12  NumTSTTakr12  \
# 0            0  9.000000e+12    9.0  El Dorado    2226.0         604.0
# 11          11  2.200000e+13   22.0   Mariposa     155.0          36.0
# 12          12  3.100000e+13   31.0     Placer    5931.0        1959.0
# 18          18  2.100000e+13   21.0      Marin    2647.0         965.0
# 29          29  2.900000e+13   29.0     Nevada    1869.0         186.0
#
#     NumERWBenchmark12  PctERWBenchmark12  NumMathBenchmark12  \
# 0               547.0              90.56               458.0
# 11               33.0              91.67                27.0
# 12             1709.0              87.24              1395.0
# 18              855.0              88.60               674.0
# 29              159.0              85.48               131.0
#
#     PctMathBenchmark12  TotNumBothBenchmark12  PctBothBenchmark12  Year  \
# 0                75.83                  442.0               73.18  2019
# ...

# %%
PCT_above_avg_act = (ACT19_ca[ACT19_ca['PctGE21']>ACT19_ca['PctGE21'].mean()].count()[1])/len(ACT19_ca)*100
PCT_above_avg_sat = (SAT19_ca[SAT19_ca['PctBothBenchmark12']>SAT19_ca['PctBothBenchmark12'].mean()].count()[1])/len(SAT19_ca)*100

# %%
PART_above_avg_act = (ACT19_ca[ACT19_ca['Participation_r_act']>ACT19_ca['Participation_r'].mean()].count()[1])/len(ACT19_ca)*100
PART_above_avg_sat = (SAT19_ca[SAT19_ca['Participation_r_sat']>SAT19_ca['Participation_r'].mean()].count()[1])/len(SAT19_ca)*100

# %%
ACT_part_avg = ACT19_ca['Participation_r'].mean()
SAT_part_avg = SAT19_ca['Participation_r'].mean()

# %%
def first_percentile(x):
    return x.quantile(0.25)

def third_percentile(x):
    return x.quantile(0.75)

ACT19_ca[['PctGE21','Participation_r_act']].aggregate(['max','min','mean',first_percentile,'median',third_percentile])
# Out:
#                     PctGE21  Participation_r_act
# max               87.100000             0.632184
# min               20.000000             0.013774
# mean              56.757407             0.147489
# first_percentile  43.560000             0.088593
# median            59.775000             0.138983
# third_percentile  71.372500             0.180408

# %%
SAT19_ca[['PctBothBenchmark12','Participation_r_sat']].aggregate(['max','min','mean',first_percentile,'median',third_percentile])
# Out:
#                   PctBothBenchmark12  Participation_r_sat
# max                        73.180000             0.507308
# min                        18.920000             0.084416
# mean                       49.723091             0.258136
# first_percentile           38.220000             0.199557
# median                     50.690000             0.241266
# third_percentile           59.825000             0.319542

# %%
print(f'The number of County that perform above average is {round(PCT_above_avg_act,2)}% for ACT test 2019 in Ca')
print(f'The number of County that perform above average is {round(PCT_above_avg_sat,2)}% for SAT test 2019 in Ca')
# Out:
# The number of County that perform above average is 48.28% for ACT test 2019 in Ca
# The number of County that perform above average is 51.72% for SAT test 2019 in Ca

# %%
print(f'The number of County that has participation rate above average is {round(PART_above_avg_act,2)}% for ACT test 2019 in Ca')
print(f'The number of County that participation rate above average is {round(PART_above_avg_sat,2)}% for SAT test 2019 in Ca')
# Out:
# The number of County that has participation rate above average is 41.38% for ACT test 2019 in Ca
# The number of County that participation rate above average is 43.1% for SAT test 2019 in Ca

# %%
ACT_high_pct = (ACT19_ca[ACT19_ca['Pct_Percentie']=='4th_quantile']['CName']).to_list()
SAT_high_pct = (SAT19_ca[SAT19_ca['Pct_Percentie']=='4th_quantile']['CName']).to_list()
ACT_low_pct = (ACT19_ca[ACT19_ca['Pct_Percentie']=='1st_quantile']['CName']).to_list()
SAT_low_pct = (SAT19_ca[SAT19_ca['Pct_Percentie']=='1st_quantile']['CName']).to_list()

ACT_high_part = (ACT19_ca[ACT19_ca['Part_Percentie']=='4th_quantile']['CName']).to_list()
SAT_high_part = (SAT19_ca[SAT19_ca['Part_Percentie']=='4th_quantile']['CName']).to_list()
ACT_low_part = (ACT19_ca[ACT19_ca['Part_Percentie']=='1st_quantile']['CName']).to_list()
SAT_low_part = (SAT19_ca[SAT19_ca['Part_Percentie']=='1st_quantile']['CName']).to_list()

# %%
counter = 0
for i in ACT_high_pct:    
     if i in  SAT_high_pct:
            counter += 1
print(f'There are {round(counter*100/len(ACT_high_pct),2)}% of County matches for ACT and SAT test which are the top 25% performer')
# Out:
# There are 64.29% of County matches for ACT and SAT test which are the top 25% performer

# %%
counter = 0
for i in ACT_high_part:    
     if i in  SAT_high_part:
            counter += 1
print(f'There are {round(counter*100/len(ACT_high_part),2)}% of County matches for ACT and SAT test which are the top 25% participation rate')
# Out:
# There are 50.0% of County matches for ACT and SAT test which are the top 25% participation rate

# %%
counter = 0
for i in ACT_low_pct:    
     if i in  SAT_low_pct:
            counter += 1
print(f'There are {round(counter*100/len(ACT_low_pct),2)}% of County matches for ACT and SAT test which are the bottom 25% performer')
# Out:
# There are 64.29% of County matches for ACT and SAT test which are the bottom 25% performer

# %%
counter = 0
for i in ACT_low_part:    
     if i in  SAT_low_part:
            counter += 1
print(f'There are {round(counter*100/len(ACT_low_part),2)}% of County matches for ACT and SAT test which are the bottom 25% participation rate')
# Out:
# There are 53.33% of County matches for ACT and SAT test which are the bottom 25% participation rate

# %%
ACT19_ca1 = ACT19_ca[['CName','PctGE21','Participation_r_act']]
SAT19_ca1 = SAT19_ca[['CName','PctBothBenchmark12','Participation_r_sat']]
Combine_t_ca = pd.merge(left = ACT19_ca1,
                       right = SAT19_ca1,
                       on = 'CName')

# %%
Combine_t_ca.head()
# Out:
#        CName  PctGE21  Participation_r_act  PctBothBenchmark12  \
# 0  Calaveras    87.10             0.068736               66.67
# 1      Marin    80.48             0.284473               68.81
# 2       Mono    80.00             0.047619               56.76
# 3     Amador    78.38             0.121311               62.26
# 4   Tuolumne    78.26             0.044402               60.00
#
#    Participation_r_sat
# 0             0.199557
# 1             0.364564
# 2             0.088095
# 3             0.173770
# 4             0.154440

# %%
ACT19_ca[['PctGE21','Participation_r_act']].describe()
# Out:
#          PctGE21  Participation_r_act
# count  54.000000            57.000000
# mean   56.757407             0.147489
# std    17.189004             0.095986
# min    20.000000             0.013774
# 25%    43.560000             0.088593
# 50%    59.775000             0.138983
# 75%    71.372500             0.180408
# max    87.100000             0.632184

# %%
SAT19_ca[['PctBothBenchmark12','Participation_r_sat']].describe()
# Out:
#        PctBothBenchmark12  Participation_r_sat
# count           55.000000            57.000000
# mean            49.723091             0.258136
# std             13.253115             0.088461
# min             18.920000             0.084416
# 25%             38.220000             0.199557
# 50%             50.690000             0.241266
# 75%             59.825000             0.319542
# max             73.180000             0.507308

# %%
Combine_t_ca.corr()
# Out:
#                       PctGE21  Participation_r_act  PctBothBenchmark12  \
# PctGE21              1.000000            -0.283747            0.709318
# Participation_r_act -0.283747             1.000000            0.182973
# PctBothBenchmark12   0.709318             0.182973            1.000000
# Participation_r_sat -0.007025             0.244695           -0.047707
#
#                      Participation_r_sat
# PctGE21                        -0.007025
# Participation_r_act             0.244695
# PctBothBenchmark12             -0.047707
# Participation_r_sat             1.000000

# %%
sns.heatmap(Combine_t_ca.corr(),annot = True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Summary:
# ##### Test Score above benchmark: There is good correleation for  the test performance for ACT and SAT in each state Califonia in 2019, but the overall performance of ACT is better than SAT.
# ##### Participation rate: The participation rate for both test has no strong correlation, will be further analyzed seperately later

# %%
GDP_ca = pd.read_csv("../data/clean data/Clean_GDP&Population_ca.csv")

# %%
Combine_t_ca['Pct_sc'] = Combine_t_ca[['PctGE21','PctBothBenchmark12']].mean(axis=1)

# %%
Combine_t_ca.head(2)
# Out:
#        CName  PctGE21  Participation_r_act  PctBothBenchmark12  \
# 0  Calaveras    87.10             0.068736               66.67
# 1      Marin    80.48             0.284473               68.81
#
#    Participation_r_sat  Pct_sc
# 0             0.199557  76.885
# 1             0.364564  74.645

# %%
GDP_ca.head(2)
# Out:
#    Unnamed: 0  GeoFips      GeoName          2017          2018          2019  \
# 0           0     6001  Alameda, CA  1.191170e+11  1.237180e+11  1.261840e+11
# 1           1     6003   Alpine, CA  9.964300e+07  1.001310e+08  1.045010e+08
#
#      CName State   County  Population (January 2019)  \
# 0  Alameda    CA  Alameda                    1669301
# 1   Alpine    CA   Alpine                       1162
#
#    Median Household Income (2017)
# 0                           95550
# 1                           55755

# %%
GDP_ca[['CName','Population (January 2019)']].sort_values(by ='Population (January 2019)', ascending=False).head()
# Out:
#              CName  Population (January 2019)
# 18     Los Angeles                   10253716
# 36       San Diego                    3351786
# 29          Orange                    3222498
# 32       Riverside                    2440124
# 35  San Bernardino                    2192203

# %%
GDP_ca['GDP_per_cap'] = GDP_ca['2019']/GDP_ca['Population (January 2019)']

# %%
GDP_ca[['CName','GDP_per_cap']].sort_values(by ='GDP_per_cap', ascending=False).head()
# Out:
#             CName    GDP_per_cap
# 37  San Francisco  199569.166924
# 42    Santa Clara  166641.934701
# 40      San Mateo  162495.077374
# 20          Marin  103375.594855
# 1          Alpine   89932.013769

# %%
GDP_ca.corr()
# it can be seen taht GDP per capital is not a good alternative of GDP in measure the whole income of a county (Low corr)
# Out:
#                                 Unnamed: 0   GeoFips      2017      2018  \
# Unnamed: 0                        1.000000  1.000000 -0.007996 -0.006032
# GeoFips                           1.000000  1.000000 -0.007996 -0.006032
# 2017                             -0.007996 -0.007996  1.000000  0.999793
# 2018                             -0.006032 -0.006032  0.999793  1.000000
# 2019                             -0.003949 -0.003949  0.999468  0.999916
# Population (January 2019)        -0.030027 -0.030027  0.954116  0.949002
# Median Household Income (2017)    0.100114  0.100114  0.379732  0.389673
# GDP_per_cap                       0.051349  0.051349  0.419731  0.432417
#
#                                     2019  Population (January 2019)  \
# Unnamed: 0                     -0.003949                  -0.030027
# GeoFips                        -0.003949                  -0.030027
# 2017                            0.999468                   0.954116
# ...

# %%
# Join all the data to be used in final EDA
GDP_ca1 = GDP_ca[['CName','2019','Population (January 2019)']]
DF_ca = pd.merge(left=Combine_t_ca,
                right=GDP_ca1,
                on = 'CName')

# %%
DF_ca.rename(columns={'2019':'GDP'},inplace=True)

# %%
DF_ca.corr()
# Out:
#                             PctGE21  Participation_r_act  PctBothBenchmark12  \
# PctGE21                    1.000000            -0.283747            0.709318
# Participation_r_act       -0.283747             1.000000            0.182973
# PctBothBenchmark12         0.709318             0.182973            1.000000
# Participation_r_sat       -0.007025             0.244695           -0.047707
# Pct_sc                     0.942986            -0.079212            0.904561
# GDP                        0.030265             0.165134           -0.009680
# Population (January 2019) -0.064290             0.122820           -0.118525
#
#                            Participation_r_sat    Pct_sc       GDP  \
# PctGE21                              -0.007025  0.942986  0.030265
# Participation_r_act                   0.244695 -0.079212  0.165134
# PctBothBenchmark12                   -0.047707  0.904561 -0.009680
# Participation_r_sat                   1.000000 -0.051447  0.549102
# ...

# %%
plt.figure(figsize=(8,4))
sns.heatmap(DF_ca.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
GDP_mean = DF_ca['GDP'].mean()
Pct_mean = DF_ca['Pct_sc'].mean()

# %%
DF_ca.describe()
# Out:
#          PctGE21  Participation_r_act  PctBothBenchmark12  \
# count  54.000000            57.000000           55.000000
# mean   56.757407             0.147489           49.723091
# std    17.189004             0.095986           13.253115
# min    20.000000             0.013774           18.920000
# 25%    43.560000             0.088593           38.220000
# 50%    59.775000             0.138983           50.690000
# 75%    71.372500             0.180408           59.825000
# max    87.100000             0.632184           73.180000
#
#        Participation_r_sat     Pct_sc           GDP  Population (January 2019)
# count            57.000000  56.000000  5.800000e+01               5.800000e+01
# mean              0.258136  53.387321  4.725881e+10               6.884020e+05
# std               0.088461  14.162286  1.087508e+11               1.493576e+06
# min               0.084416  26.770000  8.767100e+07               1.162000e+03
# ...

# %%
GDP_mean
# Out:
# 47258807396.55173

# %%
def classification_GDP(x):
    if x > DF_ca['GDP'].quantile(0.75):
        return "4th_quantile"
    elif x > DF_ca['GDP'].quantile(0.5):
        return "3rd_quantile"
    elif x > DF_ca['GDP'].quantile(0.25):
        return "2nd_quantile"
    elif x > 0:
        return "1st_quantile"
    else:
        return np.nan
    
DF_ca['GDP_Percentie'] = DF_ca['GDP'].apply(classification_GDP)

# %%
DF_ca.head(2)
# Out:
#        CName  PctGE21  Participation_r_act  PctBothBenchmark12  \
# 0  Calaveras    87.10             0.068736               66.67
# 1      Marin    80.48             0.284473               68.81
#
#    Participation_r_sat  Pct_sc           GDP  Population (January 2019)  \
# 0             0.199557  76.885  1.412753e+09                      45117
# 1             0.364564  74.645  2.717527e+10                     262879
#
#   GDP_Percentie
# 0  1st_quantile
# 1  3rd_quantile

# %%
DF_ca[DF_ca['GDP']>GDP_mean][['CName','GDP']].sort_values(by='GDP',ascending=False)
# Out:
#              CName           GDP
# 39     Los Angeles  7.037810e+11
# 5      Santa Clara  3.256660e+11
# 13          Orange  2.310360e+11
# 20       San Diego  2.140350e+11
# 31   San Francisco  1.763930e+11
# 18         Alameda  1.261840e+11
# 12       San Mateo  1.258500e+11
# 34      Sacramento  8.395113e+10
# 51  San Bernardino  8.375925e+10
# 38       Riverside  8.069054e+10
# 14    Contra Costa  7.929570e+10
# 40            Kern  4.922121e+10
# 15         Ventura  4.784653e+10

# %%
County_ab_avg = DF_ca[DF_ca['GDP']>GDP_mean][['CName']].values

# %%
Num_ab_GDP = DF_ca[DF_ca['GDP']>GDP_mean][['GDP']].count()[0]

# %%
Per_GDPabovemean = 100* (DF_ca[DF_ca['GDP']>GDP_mean][['CName']].count())/len(DF_ca)

# %%
Pct_class = DF_ca.groupby('GDP_Percentie')['Pct_sc'].mean()

# %%
Part_act_class = DF_ca.groupby('GDP_Percentie')['Participation_r_act'].mean()

# %%
Part_sat_class = DF_ca.groupby('GDP_Percentie')['Participation_r_sat'].mean()

# %%
DF_ca.describe()
# Out:
#          PctGE21  Participation_r_act  PctBothBenchmark12  \
# count  54.000000            57.000000           55.000000
# mean   56.757407             0.147489           49.723091
# std    17.189004             0.095986           13.253115
# min    20.000000             0.013774           18.920000
# 25%    43.560000             0.088593           38.220000
# 50%    59.775000             0.138983           50.690000
# 75%    71.372500             0.180408           59.825000
# max    87.100000             0.632184           73.180000
#
#        Participation_r_sat     Pct_sc           GDP  Population (January 2019)
# count            57.000000  56.000000  5.800000e+01               5.800000e+01
# mean              0.258136  53.387321  4.725881e+10               6.884020e+05
# std               0.088461  14.162286  1.087508e+11               1.493576e+06
# min               0.084416  26.770000  8.767100e+07               1.162000e+03
# ...

# %%
DF_ca[['CName','GDP']].sort_values(by = 'GDP',ascending=False).head()
# Out:
#             CName           GDP
# 39    Los Angeles  7.037810e+11
# 5     Santa Clara  3.256660e+11
# 13         Orange  2.310360e+11
# 20      San Diego  2.140350e+11
# 31  San Francisco  1.763930e+11

# %%
print(f'The mean score percentage for both test in Califonia is {round(Pct_mean,2)}%')
print(f'The mean GDP for counties in Califonia is ${round(GDP_mean)}, and {Num_ab_GDP} counties has GDP higher than average \n which equivalent to {round(Per_GDPabovemean[0],2)}% of all counties')
print(f'The counties are \n {County_ab_avg[0:Num_ab_GDP]}')
# Out:
# The mean score percentage for both test in Califonia is 53.39%
# The mean GDP for counties in Califonia is $47258807397, and 13 counties has GDP higher than average
#  which equivalent to 22.41% of all counties
# The counties are
#  [['Santa Clara']
#  ['San Mateo']
#  ['Orange']
#  ['Contra Costa']
#  ['Ventura']
#  ['Alameda']
#  ['San Diego']
#  ['San Francisco']
#  ['Sacramento']
#  ['Riverside']
#  ['Los Angeles']
#  ['Kern']
#  ['San Bernardino']]

# %%
print(f'The counties in top 25% GDP has the average scored percentage of {round(Pct_top[3],2)}%')
print(f'The counties in quantile of 50-75% GDP has the average scored percentage of {round(Pct_top[2],2)}%')
print(f'The counties in quantile of 25-50% GDP has the average scored percentage of {round(Pct_top[1],2)}%')
print(f'The counties in bottom 25% GDP has the average scored percentage of {round(Pct_top[0],2)}%')
print('There is no significant different in test performance for different range of GDP')
# Out:
# The counties in top 25% GDP has the average scored percentage of 52.24%
# The counties in quantile of 50-75% GDP has the average scored percentage of 54.75%
# The counties in quantile of 25-50% GDP has the average scored percentage of 53.05%
# The counties in bottom 25% GDP has the average scored percentage of 53.6%
# There is no significant different in test performance for different range of GDP

# %%
print(f'The counties in top 25% GDP has the participation rate in ACT of {round(Part_act_class[3],3)*100}%')
print(f'The counties in quantile of 50-75% GDP has participation rate in ACT of {round(Part_act_class[2],3)*100}%')
print(f'The counties in quantile of 25-50% GDP has participation rate in ACT of {round(Part_act_class[1],3)*100}%')
print(f'The counties in bottom 25% GDP has participation rate in ACT of {round(Part_act_class[0],3)*100}%')
print(f'There is small trend up of participation rate with GDP and \n the top 50% GDP county has higher or equal to the average rate:{round(ACT_part_avg,2)*100}%')
# Out:
# The counties in top 25% GDP has the participation rate in ACT of 17.2%
# The counties in quantile of 50-75% GDP has participation rate in ACT of 15.4%
# The counties in quantile of 25-50% GDP has participation rate in ACT of 13.100000000000001%
# The counties in bottom 25% GDP has participation rate in ACT of 13.200000000000001%
# There is small trend up of participation rate with GDP and
#  the top 50% GDP county has higher or equal to the average rate:15.0%

# %%
print(f'The counties in top 25% GDP has the participation rate in SAT of {round(Part_sat_class[3],3)*100}%')
print(f'The counties in quantile of 50-75% GDP has participation rate in SAT of {round(Part_sat_class[2],3)*100}%')
print(f'The counties in quantile of 25-50% GDP has participation rate in SAT of {round(Part_sat_class[1],3)*100}%')
print(f'The counties in bottom 25% GDP has participation rate in SAT of {round(Part_sat_class[0],3)*100}%')
print(f'There is significant trend up of participation rate with GDP and \n the top 50% GDP county has higher or equal to the average rate:{round(SAT_part_avg,2)*100}%')
# Out:
# The counties in top 25% GDP has the participation rate in SAT of 36.0%
# The counties in quantile of 50-75% GDP has participation rate in SAT of 27.900000000000002%
# The counties in quantile of 25-50% GDP has participation rate in SAT of 20.1%
# The counties in bottom 25% GDP has participation rate in SAT of 18.5%
# There is significant trend up of participation rate with GDP and
#  the top 50% GDP county has higher or equal to the average rate:26.0%

# %% [markdown]
# ## Conclusion of EDA
# ### The performance of ACT and SAT test by county is comparable in Califonia
# ###  There is 13 counties has the GDP higher than the average GDP
# ###  There average GDP of Clifonia in 2019 is 47,258 million dollar
# ###  Sierra has the lowest GDP and Los Angeles has the highest GDP
# ###  The test performance of the student do not has relation with the GDP of the county
# ###  For both test, higher GDP county has higher participation rate
# ###  Participation rate of SAT is higher than ACT, and increase significantly with GDP

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Code
GDP_ca = pd.read_csv("../data/clean data/Clean_GDP_ca.csv")

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
